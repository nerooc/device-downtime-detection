# %% [markdown]
# # Korelacje

# %%
# By zaimportować moduły z głównego folderu
# %cd ..
# Out:
# /Users/nerooc/Documents/Studia/device-downtime-detection

# %%
import import_ipynb
import seaborn as sns
from matplotlib import rcParams
from data_preprocessing import split_working_faulty_blocks

rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# Za pomocą funkcji preprocesującej dane, otrzymujemy nasze zestawy

# %%
working_blocks_df, faulty_blocks_df = split_working_faulty_blocks(True)

# %% [markdown]
# ## Bloki działające

# %%
corr = working_blocks_df.corr()
sns.heatmap(corr, cmap="mako", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bloki awaryjne

# %%
corr = faulty_blocks_df.corr()
sns.heatmap(corr, cmap="mako", annot=True)
# Out:
# <AxesSubplot:>
