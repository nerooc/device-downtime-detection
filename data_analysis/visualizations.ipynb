# %% [markdown]
# # Wizualizacje

# %%
# By zaimportować moduły z głównego folderu
# %cd ..
# Out:
# /Users/nerooc/Documents/Studia/device-downtime-detection

# %%
import import_ipynb
import seaborn as sns
import matplotlib.pyplot as plt
from data_preprocessing import split_working_faulty_blocks

plt.rcParams["figure.figsize"] = (8, 5)
# Out:
# importing Jupyter notebook from data_preprocessing.ipynb

# %%
# Parametr "True" by dane były znormalizowane
working_blocks_df, faulty_blocks_df = split_working_faulty_blocks()
working_blocks_df_normalized, faulty_blocks_df_normalized = split_working_faulty_blocks(True)

working_blocks = working_blocks_df.values.tolist()
faulty_blocks = faulty_blocks_df.values.tolist()

working_blocks_normalized = working_blocks_df_normalized.values.tolist()
faulty_blocks_normalized = faulty_blocks_df_normalized.values.tolist()

# %% [markdown]
# ## Przedstawienie danych na histogramach

# %%
plt.style.use('classic')
sns.set()

# %% [markdown]
# ### Bloki działające

# %%
working_blocks_hist = working_blocks_df.hist(column=working_blocks_df.columns, figsize=(10,10), color="slateblue")

# %% [markdown]
# ### Bloki awaryjne

# %%
faulty_blocks_hist = faulty_blocks_df.hist(column=faulty_blocks_df.columns, figsize=(10,10), color="slateblue")

# %%
plt.plot(working_blocks_normalized[0], color="slateblue")
plt.title('Wykres wartości elementów pierwszego działającego bloku')
# Out:
# Text(0.5, 1.0, 'Wykres wartości elementów pierwszego działającego bloku')

# %% [markdown]
# ## Pairplot
# Wykorzystujemy metodę pairplot biblioteki Seaborn na naszych danych, w celu uzyskania sporej ilości zwizualizowanych statystyk.

# %% [markdown]
# ### Bloki działające

# %%
sns.pairplot(working_blocks_df_normalized)

# %% [markdown]
# ### Bloki awaryjne

# %%
sns.pairplot(faulty_blocks_df_normalized)
